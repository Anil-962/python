# %%
import pandas as pd
df = pd.read_csv('/content/city_temperature.csv', encoding='latin1')
df
# Out:
#         Region      Country  State     City  Month   Day    Year  \
# 0       Africa      Algeria    NaN  Algiers    1.0   1.0  1995.0
# 1       Africa      Algeria    NaN  Algiers    1.0   2.0  1995.0
# 2       Africa      Algeria    NaN  Algiers    1.0   3.0  1995.0
# 3       Africa      Algeria    NaN  Algiers    1.0   4.0  1995.0
# 4       Africa      Algeria    NaN  Algiers    1.0   5.0  1995.0
# ...        ...          ...    ...      ...    ...   ...     ...
# 102410  Africa  Ivory Coast    NaN  Abidjan    3.0   9.0  2011.0
# 102411  Africa  Ivory Coast    NaN  Abidjan    3.0  10.0  2011.0
# 102412  Africa  Ivory Coast    NaN  Abidjan    3.0  11.0  2011.0
# 102413  Africa  Ivory Coast    NaN  Abidjan    3.0  12.0  2011.0
# 102414  Africa      Ivory C    NaN      NaN    NaN   NaN     NaN
#
#         AvgTemperature
# 0                 64.2
# 1                 49.4
# 2                 48.8
# 3                 46.4
# 4                 47.9
# ...                ...
# ...

# %%
df['AvgTemperature'].max()
# Out:
# 100.2

# %%
df['AvgTemperature'].min()
# Out:
# -99.0

# %%
df.fillna(0, inplace=True)
print(df)
# Out:
#         Region      Country  State     City  Month   Day    Year  \
# 0       Africa      Algeria    0.0  Algiers    1.0   1.0  1995.0
# 1       Africa      Algeria    0.0  Algiers    1.0   2.0  1995.0
# 2       Africa      Algeria    0.0  Algiers    1.0   3.0  1995.0
# 3       Africa      Algeria    0.0  Algiers    1.0   4.0  1995.0
# 4       Africa      Algeria    0.0  Algiers    1.0   5.0  1995.0
# ...        ...          ...    ...      ...    ...   ...     ...
# 102410  Africa  Ivory Coast    0.0  Abidjan    3.0   9.0  2011.0
# 102411  Africa  Ivory Coast    0.0  Abidjan    3.0  10.0  2011.0
# 102412  Africa  Ivory Coast    0.0  Abidjan    3.0  11.0  2011.0
# 102413  Africa  Ivory Coast    0.0  Abidjan    3.0  12.0  2011.0
# 102414  Africa      Ivory C    0.0        0    0.0   0.0     0.0
#
#         AvgTemperature
# 0                 64.2
# 1                 49.4
# 2                 48.8
# 3                 46.4
# 4                 47.9
# ...                ...
# ...

# %%
df
# Out:
#         Region      Country  State     City  Month   Day    Year  \
# 0       Africa      Algeria    0.0  Algiers    1.0   1.0  1995.0
# 1       Africa      Algeria    0.0  Algiers    1.0   2.0  1995.0
# 2       Africa      Algeria    0.0  Algiers    1.0   3.0  1995.0
# 3       Africa      Algeria    0.0  Algiers    1.0   4.0  1995.0
# 4       Africa      Algeria    0.0  Algiers    1.0   5.0  1995.0
# ...        ...          ...    ...      ...    ...   ...     ...
# 102410  Africa  Ivory Coast    0.0  Abidjan    3.0   9.0  2011.0
# 102411  Africa  Ivory Coast    0.0  Abidjan    3.0  10.0  2011.0
# 102412  Africa  Ivory Coast    0.0  Abidjan    3.0  11.0  2011.0
# 102413  Africa  Ivory Coast    0.0  Abidjan    3.0  12.0  2011.0
# 102414  Africa      Ivory C    0.0        0    0.0   0.0     0.0
#
#         AvgTemperature
# 0                 64.2
# 1                 49.4
# 2                 48.8
# 3                 46.4
# 4                 47.9
# ...                ...
# ...

# %%
df['Year'][df['AvgTemperature']==df['AvgTemperature'].max()]
# Out:
# 50515    2019.0
# Name: Year, dtype: float64

# %%
df['Year'][df['AvgTemperature']==df['AvgTemperature'].mean()]
# Out:
# Series([], Name: Year, dtype: float64)

# %%
df['Year'][df['AvgTemperature']==df['AvgTemperature'].min()]
# Out:
# 220       1995.0
# 221       1995.0
# 408       1996.0
# 409       1996.0
# 1453      1998.0
#            ...
# 101121    2007.0
# 101384    2008.0
# 101385    2008.0
# 101514    2008.0
# 101711    2009.0
# Name: Year, Length: 14639, dtype: float64
