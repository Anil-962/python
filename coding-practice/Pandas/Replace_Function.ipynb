# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/Wether.csv')
df
# Out:
#            Day   Temp   Wind     Event
# 0   01-01-2025     32      6      Rain
# 1   01-02-2025     43 -99999     Sunny
# 2   01-03-2025 -99999      5  No Event
# 3   01-04-2025     32      6      Snow
# 4   01-05-2025     12 -99999      Rain
# 5   01-06-2025     32      4  No Event
# 6   01-07-2025 -99999      4  No Event
# 7   01-08-2025 -99999 -99999      Snow
# 8   01-09-2025     23 -99999  No Event
# 9   01-10-2025     25      5      Rain
# 10  01-11-2025     34      6  No Event
# 11  01-12-2025 -99999      8     Sunny

# %%
new_df = df.replace(-99999,np.nan)
new_df
# Out:
#            Day  Temp  Wind     Event
# 0   01-01-2025  32.0   6.0      Rain
# 1   01-02-2025  43.0   NaN     Sunny
# 2   01-03-2025   NaN   5.0  No Event
# 3   01-04-2025  32.0   6.0      Snow
# 4   01-05-2025  12.0   NaN      Rain
# 5   01-06-2025  32.0   4.0  No Event
# 6   01-07-2025   NaN   4.0  No Event
# 7   01-08-2025   NaN   NaN      Snow
# 8   01-09-2025  23.0   NaN  No Event
# 9   01-10-2025  25.0   5.0      Rain
# 10  01-11-2025  34.0   6.0  No Event
# 11  01-12-2025   NaN   8.0     Sunny

# %%
# Out:
#            Day   Temp     Wind     Event
# 0   01-01-2025     32      6.0      Rain
# 1   01-02-2025     43      NaN     Sunny
# 2   01-03-2025 -99999      5.0  No Event
# 3   01-04-2025     32      6.0      Snow
# 4   01-05-2025     12      NaN      Rain
# 5   01-06-2025     32      4.0  No Event
# 6   01-07-2025 -99999      4.0  No Event
# 7   01-08-2025 -99999      NaN      Snow
# 8   01-09-2025     23 -99999.0  No Event
# 9   01-10-2025     25      5.0      Rain
# 10  01-11-2025     34      6.0  No Event
# 11  01-12-2025 -99999      8.0     Sunny
