# %%
import pandas as pd
df = pd.read_csv("Temp.csv")
df
# Out:
#           Day  temp  WindSpeed  Event
# 0  01-01-2025    32          6   Rain
# 1  01-02-2025    35          8  Sunny
# 2  01-03-2025    28          2   Snow
# 3  01-04-2025    12          7   Snow
# 4  01-05-2025    34          4   Rain
# 5  01-06-2025    32          2  Sunny

# %%
rows,colums = df.shape

# %%
rows
# Out:
# 6

# %%
colums
# Out:
# 4

# %%
df.head(2)
# Out:
#           Day  temp  WindSpeed  Event
# 0  01-01-2025    32          6   Rain
# 1  01-02-2025    35          8  Sunny
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['temp'].plot(kind='hist', bins=20, title='temp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['WindSpeed'].plot(kind='hist', bins=20, title='WindSpeed')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Day').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.tail(2)
# Out:
#           Day  temp  WindSpeed  Event
# 4  01-05-2025    34          4   Rain
# 5  01-06-2025    32          2  Sunny

# %%
df[2:5]
# Out:
#           Day  temp  WindSpeed Event
# 2  01-03-2025    28          2  Snow
# 3  01-04-2025    12          7  Snow
# 4  01-05-2025    34          4  Rain

# %%
df.columns
# Out:
# Index(['Day', 'temp', 'WindSpeed', 'Event'], dtype='object')

# %%
df.Day
# Out:
# 0    01-01-2025
# 1    01-02-2025
# 2    01-03-2025
# 3    01-04-2025
# 4    01-05-2025
# 5    01-06-2025
# Name: Day, dtype: object

# %%
df['Event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: Event, dtype: object

# %%
df[['Event','Day']]
# Out:
#    Event         Day
# 0   Rain  01-01-2025
# 1  Sunny  01-02-2025
# 2   Snow  01-03-2025
# 3   Snow  01-04-2025
# 4   Rain  01-05-2025
# 5  Sunny  01-06-2025

# %%
df['temp'].max()
# Out:
# 35

# %%
df['temp'].min()
# Out:
# 12

# %%
df.describe()
# Out:
#             temp  WindSpeed
# count   6.000000   6.000000
# mean   28.833333   4.833333
# std     8.588752   2.562551
# min    12.000000   2.000000
# 25%    29.000000   2.500000
# 50%    32.000000   5.000000
# 75%    33.500000   6.750000
# max    35.000000   8.000000

# %%
df[df.temp>=30]
# Out:
#           Day  temp  WindSpeed  Event
# 0  01-01-2025    32          6   Rain
# 1  01-02-2025    35          8  Sunny
# 4  01-05-2025    34          4   Rain
# 5  01-06-2025    32          2  Sunny

# %%
df[df.temp<=30]
# Out:
#           Day  temp  WindSpeed Event
# 2  01-03-2025    28          2  Snow
# 3  01-04-2025    12          7  Snow

# %%
df
# Out:
#           Day  temp  WindSpeed  Event
# 0  01-01-2025    32          6   Rain
# 1  01-02-2025    35          8  Sunny
# 2  01-03-2025    28          2   Snow
# 3  01-04-2025    12          7   Snow
# 4  01-05-2025    34          4   Rain
# 5  01-06-2025    32          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('Day',inplace=True)

# %%
df
# Out:
#             temp  WindSpeed  Event
# Day
# 01-01-2025    32          6   Rain
# 01-02-2025    35          8  Sunny
# 01-03-2025    28          2   Snow
# 01-04-2025    12          7   Snow
# 01-05-2025    34          4   Rain
# 01-06-2025    32          2  Sunny

# %%
df.loc['01-01-2025']
# Out:
# temp           32
# WindSpeed       6
# Event        Rain
# Name: 01-01-2025, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#           Day  temp  WindSpeed  Event
# 0  01-01-2025    32          6   Rain
# 1  01-02-2025    35          8  Sunny
# 2  01-03-2025    28          2   Snow
# 3  01-04-2025    12          7   Snow
# 4  01-05-2025    34          4   Rain
# 5  01-06-2025    32          2  Sunny
